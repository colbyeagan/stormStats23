# %% [markdown]
# # STORM STATS IPYNB
#
# ## Plus/Minus documentation
# ### First Steps:
# 1. Adjust the playersList array below to match the numbers of the players in the csv file
# 2. Ensure the columns in the CSV are named 'Plus', 'Minus', 'Plus/Minus', and '# Possessions' WITHOUT the quotation marks, case sensitive, get spelling correct!
# 3. Put the CSV file into the same folde/directory as this program.
# 4. Initialize an 'object' of the csv file with the syntax "Game1: GameFile = GameFile("Plus_Minus.csv", "x", playersList)"
#     - Change the "Game1" to better identify the game you are analyzing.
#     - Change the "PlusMinus.csv" to match the name of the CSV you want to analyze.
#     - Change the "x" to be whatever character marks a player as being in the game.

# %%
from plusMin import GameFile
playersList = ['0', '1', '3', '4', '5','10', '12', '20', '21', '22', '23', '25', '33', '34']
Game1: GameFile = GameFile("Plus_Minus.csv", "x", playersList)

# %% [markdown]
# # Functionality/Methods
# ## plusStatsListCombo
#     - plusStatsListCombo displays all plus stats of all N combinations in the game
#     - Syntax: Game1.plusStatsListCombo(N Combination, True/False (if True, will sort by plus/per/possession))
#
# ## minusStatsListCombo
#     - minusStatsListCombo displays all minus stats of all N combinations in the game
#     - Syntax: Game1.minusStatsListCombo(N Combination, True/False (if True, will sort by minus/per/possession))
#
# ## plusMinusStatsListCombo
#     - plusMinusStatsListCombo displays all plus/minus stats of all N combinations in the game
#     - Syntax: Game1.plusMinusStatsListCombo(N Combination, True/False (if True, will sort by plus-minus/per/possession))
#
# ## allStatsListCombo
#     - allStatsListCombo displays all stats of all N combinations in the game
#     - Syntax: Game1.allStatsListCombo(N Combination)

# %%
Game1.allStatsListCombo(3)
#Game1.plusStatsListCombo(3, True)
#Game1.minusStatsListCombo(2, True)
#Game1.plusMinusStatsListCombo(3, True)
#Game1.allStatsListCombo(2)
# Out:
# 100%|██████████| 259/259 [00:01<00:00, 160.99it/s]
# 0,1,4 --- {'Plus': 12, 'Minus': 0, 'Plus/Minus': 12}
# 0,1,10 --- {'Plus': 17, 'Minus': 4, 'Plus/Minus': 13}
# 0,1,12 --- {'Plus': 17, 'Minus': 4, 'Plus/Minus': 13}
# 0,1,21 --- {'Plus': 13, 'Minus': 0, 'Plus/Minus': 13}
# 0,1,33 --- {'Plus': 12, 'Minus': 0, 'Plus/Minus': 12}
# 0,4,10 --- {'Plus': 14, 'Minus': 0, 'Plus/Minus': 14}
# 0,4,12 --- {'Plus': 14, 'Minus': 0, 'Plus/Minus': 14}
# 0,4,21 --- {'Plus': 12, 'Minus': 0, 'Plus/Minus': 12}
# 0,4,33 --- {'Plus': 14, 'Minus': 0, 'Plus/Minus': 14}
# 0,10,12 --- {'Plus': 145, 'Minus': 85, 'Plus/Minus': 60}
# 0,10,21 --- {'Plus': 147, 'Minus': 85, 'Plus/Minus': 62}
# 0,10,33 --- {'Plus': 127, 'Minus': 78, 'Plus/Minus': 49}
# 0,12,21 --- {'Plus': 156, 'Minus': 88, 'Plus/Minus': 68}
# 0,12,33 --- {'Plus': 139, 'Minus': 93, 'Plus/Minus': 46}
# 0,21,33 --- {'Plus': 148, 'Minus': 94, 'Plus/Minus': 54}
# 1,4,10 --- {'Plus': 12, 'Minus': 0, 'Plus/Minus': 12}
# ...
